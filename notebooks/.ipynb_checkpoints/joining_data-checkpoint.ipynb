# %%
import numpy as np
import pandas as pd
import math
import sqlite3
from sqlite3 import Error
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data transformation, joining
# __Join the data from Part 1 with the data from Part 2 to create a new dataframe.__

# %% [markdown]
# Load csv files to dataframe

# %%
yelp_df = pd.read_csv("yelp_df.csv")
foursquare_df = pd.read_csv("foursquare_df.csv")
station_df = pd.read_csv("station_df.csv")

# %% [markdown]
# Drop business id column in foursquare dataframe

# %%
foursquare_df = foursquare_df.drop('fsq_id',axis = 1)

# %% [markdown]
# Rename collumn to prepare for joining table

# %%
yelp_df.rename(columns = {'location.address1':'address'}, inplace = True)
foursquare_df.rename(columns = {'location.address':'address'}, inplace = True)

# %% [markdown]
# Join foursquare dataframe and yelp dataframe to get a new dataframe

# %%
join_df = pd.merge(yelp_df, foursquare_df, how="outer", on=["name", "address","station latitude","station longitude"])

# %% [markdown]
# Create function to group two column in join_df dataframe into a new one. The new value is the mean of the two old one

# %%
def join_column(one,two,new,dataframe):
    dataframe[new] = pd.Series()
    for index in range(len(dataframe)):
        if math.isnan(dataframe[one][index]) and math.isnan(dataframe[two][index]): dataframe[new][index] = np.nan
        elif math.isnan(dataframe[one][index]) and ~math.isnan(dataframe[two][index]): dataframe[new][index] = dataframe[two][index]
        elif ~math.isnan(dataframe[one][index]) and math.isnan(dataframe[two][index]): dataframe[new][index] = dataframe[one][index]
        else: dataframe[new][index] = (dataframe[one][index] + dataframe[two][index])/2     
    dataframe.drop([one,two],axis=1,inplace=True)

# %% [markdown]
# Join two column with similar type to a new one

# %%
join_column('rating_x','rating_y','rating',join_df)
join_column('station id_x','station id_y','station id',join_df)
join_column('price_x','price_y','price',join_df)
join_column('distance_x','distance_y','distance',join_df)
join_column('number of bikes_x','number of bikes_y','number of bikes',join_df)
# Out:
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dataframe[new] = pd.Series()
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif ~math.isnan(dataframe[one][index]) and math.isnan(dataframe[two][index]): dataframe[new][index] = dataframe[one][index]
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   else: dataframe[new][index] = (dataframe[one][index] + dataframe[two][index])/2
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif math.isnan(dataframe[one][index]) and ~math.isnan(dataframe[two][index]): dataframe[new][index] = dataframe[two][index]
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if math.isnan(dataframe[one][index]) and math.isnan(dataframe[two][index]): dataframe[new][index] = np.nan
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dataframe[new] = pd.Series()
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif ~math.isnan(dataframe[one][index]) and math.isnan(dataframe[two][index]): dataframe[new][index] = dataframe[one][index]
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   else: dataframe[new][index] = (dataframe[one][index] + dataframe[two][index])/2
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif math.isnan(dataframe[one][index]) and ~math.isnan(dataframe[two][index]): dataframe[new][index] = dataframe[two][index]
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dataframe[new] = pd.Series()
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif ~math.isnan(dataframe[one][index]) and math.isnan(dataframe[two][index]): dataframe[new][index] = dataframe[one][index]
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if math.isnan(dataframe[one][index]) and math.isnan(dataframe[two][index]): dataframe[new][index] = np.nan
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   else: dataframe[new][index] = (dataframe[one][index] + dataframe[two][index])/2
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif math.isnan(dataframe[one][index]) and ~math.isnan(dataframe[two][index]): dataframe[new][index] = dataframe[two][index]
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dataframe[new] = pd.Series()
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif ~math.isnan(dataframe[one][index]) and math.isnan(dataframe[two][index]): dataframe[new][index] = dataframe[one][index]
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   else: dataframe[new][index] = (dataframe[one][index] + dataframe[two][index])/2
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif math.isnan(dataframe[one][index]) and ~math.isnan(dataframe[two][index]): dataframe[new][index] = dataframe[two][index]
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dataframe[new] = pd.Series()
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif ~math.isnan(dataframe[one][index]) and math.isnan(dataframe[two][index]): dataframe[new][index] = dataframe[one][index]
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   else: dataframe[new][index] = (dataframe[one][index] + dataframe[two][index])/2
# C:\Users\bosst\AppData\Local\Temp\ipykernel_22728\619000657.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif math.isnan(dataframe[one][index]) and ~math.isnan(dataframe[two][index]): dataframe[new][index] = dataframe[two][index]

# %% [markdown]
# __Create new id columns for each restaurants and format different data in join_df__

# %% [markdown]
# Create new id for each restaurant

# %%
join_df["restaurant id"] = join_df.index + 1

# %% [markdown]
# Format review count to datatype Int64

# %%
join_df["review_count"] = pd.to_numeric(
    join_df["review_count"], 
    errors='coerce'
).astype('Int64')

# %% [markdown]
# Format number of bikes to int

# %%
join_df["number of bikes"] = join_df["number of bikes"].astype(int)

# %% [markdown]
# Format station id to int

# %%
join_df["station id"] = join_df["station id"].astype(int)

# %% [markdown]
# # Data cleaning and auditing

# %% [markdown]
# __Remove duplicate rows with same restaurant name, address and station id__

# %%
join_df = join_df.drop_duplicates(subset = ['name','address','station id'])

# %% [markdown]
# __Remove all row with NULL data__

# %%
join_df = join_df.dropna(axis=0)

# %% [markdown]
# __Remove restaurant id columns__

# %%
join_df = join_df.drop(['station longitude', 'station latitude'], axis = 1)

# %% [markdown]
# __Outlier detecting and removal for review count and distance__

# %% [markdown]
# Overview of the dataset descriptive statistics

# %%
join_df.describe()
# Out:
#        review_count       rating   station id        price     distance  \
# count        2801.0  2801.000000  2801.000000  2801.000000  2801.000000
# mean     406.981078     7.839432    97.984648     1.918779   572.116766
# std      476.070562     1.116413    56.306611     0.519365   316.271307
# min             1.0     2.000000     1.000000     1.000000     9.416067
# 25%            92.0     7.200000    50.000000     2.000000   303.980216
# 50%           240.0     8.000000    98.000000     2.000000   561.158745
# 75%           546.0     8.600000   145.000000     2.000000   834.971045
# max          3347.0    10.000000   200.000000     4.000000  1380.775862
#
#        number of bikes  restaurant id
# count      2801.000000    2801.000000
# mean          5.805427    1880.072831
# std           4.095074    1082.684448
# min           0.000000       1.000000
# 25%           3.000000     941.000000
# 50%           5.000000    1874.000000
# 75%           9.000000    2789.000000
# max          23.000000    3826.000000

# %% [markdown]
# Histogram to visually see if any outlier exist for review count, distance, rating, and price

# %%
join_df[['review_count','distance','rating','price']].hist()
# Out:
# array([[<Axes: title={'center': 'review_count'}>,
#         <Axes: title={'center': 'distance'}>],
#        [<Axes: title={'center': 'rating'}>,
#         <Axes: title={'center': 'price'}>]], dtype=object)

# %% [markdown]
# We can see that there're outliers in the review_count column and rating. Remove any row with review count that's more than 3 standard deviation from the mean

# %%
reviewCountUpperLimit = join_df['review_count'].mean() + join_df['review_count'].std()*3
indexReviewCount = join_df[join_df['review_count'] > reviewCountUpperLimit].index
join_df.drop(indexReviewCount, inplace=True)

ratingUnderLimit = join_df['rating'].mean() - join_df['rating'].std()*3
indexRating = join_df[join_df['rating'] < ratingUnderLimit].index
join_df.drop(indexRating, inplace=True)

# %% [markdown]
# __Create new analytics dataframe with stations information, the average rating of nearby restaurant, average rating, averrage review count, number of nearby restaurant,average distance to near by resturant__

# %% [markdown]
# Create analytics_df to contain all average rating of nearby restaurant, average rating, averrage review count group by the station id

# %%
analytics_df = join_df[['station id','review_count','rating','price','distance','number of bikes']].groupby('station id').mean()

# %% [markdown]
# Add `restaurant count` column to count number of restaurant near each station

# %%
analytics_df['restaurant count'] = join_df[['restaurant id','station id']].groupby('station id').count()

# %% [markdown]
# Add `high rating count` to count number of 4 or 5 rating near station

# %%
analytics_df['high rating count'] = join_df[join_df['rating'] >= 4][['restaurant id','station id']].groupby('station id').count()

# %% [markdown]
# Rename column

# %%
analytics_df = analytics_df.rename(columns={"review_count": "avg review count", "rating": "avg rating", "price": "avg price","distance":"avg distance"}, errors="raise")

# %%
analytics_df
# Out:
#             avg review count  avg rating  avg price  avg distance  \
# station id
# 1                    446.625    8.228125   1.937500    377.065030
# 2                 158.444444    8.016667   1.444444    934.161800
# 3                 224.933333    7.956667   2.066667    727.466719
# 4                 473.066667    7.793333   1.833333    436.893646
# 5                 343.333333    8.300000   1.966667    580.341278
# ...                      ...         ...        ...           ...
# 196                59.888889    6.194444   1.500000    558.746236
# 197                     54.0    6.125000   1.500000    421.317180
# 198               101.555556    7.111111   1.722222    994.637096
# 199                56.545455    6.068182   1.500000    712.451585
# 200                    380.5    8.278571   1.928571    272.333933
#
#             number of bikes  restaurant count  high rating count
# station id
# 1                       5.0                16                 16
# 2                       9.0                 9                  9
# 3                       7.0                15                 15
# 4                       9.0                15                 15
# 5                      15.0                15                 15
# ...                     ...               ...                ...
# 196                     1.0                 9                  9
# 197                     0.0                10                 10
# 198                    23.0                 9                  9
# 199                     6.0                11                 11
# 200                     4.0                14                 14
#
# [199 rows x 7 columns]

# %% [markdown]
# Export analytics dataframe to a csv file

# %%
analytics_df.to_csv("analytics_df.csv")

# %% [markdown]
# Scatter plot to see relationship between each data to the number of bikes

# %%
fig, axe = plt.subplots(nrows = 2, ncols = 3, figsize=(15,15))

axe[0,0].scatter(x = analytics_df['number of bikes'],y = analytics_df['avg distance'])
axe[0,0].set_xlabel('number of bikes')
axe[0,0].set_ylabel('avg distance')
axe[0,0].grid()

axe[0,1].scatter(x = analytics_df['number of bikes'],y = analytics_df['avg review count'])
axe[0,1].set_xlabel('number of bikes')
axe[0,1].set_ylabel('avg review count')
axe[0,1].grid()

axe[0,2].scatter(x = analytics_df['number of bikes'],y = analytics_df['avg rating'])
axe[0,2].set_xlabel('number of bikes')
axe[0,2].set_ylabel('avg rating')
axe[0,2].grid()

axe[1,0].scatter(x = analytics_df['number of bikes'],y = analytics_df['avg price'])
axe[1,0].set_xlabel('number of bikes')
axe[1,0].set_ylabel('avg price')
axe[1,0].grid()

axe[1,1].scatter(x = analytics_df['number of bikes'],y = analytics_df['restaurant count'])
axe[1,1].set_xlabel('number of bikes')
axe[1,1].set_ylabel('restaurant count')
axe[1,1].grid()

axe[1,2].scatter(x = analytics_df['number of bikes'],y = analytics_df['high rating count'])
axe[1,2].set_xlabel('number of bikes')
axe[1,2].set_ylabel('high rating count')
axe[1,2].grid()

plt.show()

# %% [markdown]
# From the chart, graphically, there's no realation ship between the any of the independant variables and the dependant variable

# %% [markdown]
# Heatmap to see correlation between each data

# %%
sns.heatmap(
    analytics_df.corr(),
    annot = True,
)
# Out:
# <Axes: >

# %% [markdown]
# From the heat map, there is no really strong correlation between the number of bikes and any other data

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %% [markdown]
# Function to create connection to database

# %%
def create_connection(path):
    connection = None
    try:
        connection = sqlite3.connect(path)
        print("Connection to SQLite DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")
    return connection

# %% [markdown]
# Create and connect to restaurants database

# %%
connection = create_connection("restaurants.sqlite")
# Out:
# Connection to SQLite DB successful

# %% [markdown]
# Function to execute querry

# %%
def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query executed successfully")
    except Error as e:
        print(f"The error '{e}' occurred")

# %% [markdown]
# Create table querry

# %%
create_restaurant_location_table = """
CREATE TABLE IF NOT EXISTS restaurant_location (
  "restaurant id" INTEGER PRIMARY KEY,
  "address" TEXT,
  "distance" NUMERIC NOT NULL
);
"""
create_restaurant_info_table = """
CREATE TABLE IF NOT EXISTS restaurant_info (
  "restaurant id" INTEGER PRIMARY KEY,
  "station id" INTEGER NOT NULL,
  "name" TEXT,
  "price" NUMERIC,
  "review_count" INTEGER,
  "rating" NUMERIC
);
"""
create_station_table = """
CREATE TABLE IF NOT EXISTS station (
  "station id" INTEGER PRIMARY KEY,
  "station latitude" NUMERIC NOT NULL,
  "station longitude" NUMERIC NOT NULL,
  "number of bikes" INT NOT NULL
);
"""

# %% [markdown]
# Execute Create table querry

# %%
execute_query(connection, create_restaurant_location_table)
execute_query(connection, create_restaurant_info_table)
execute_query(connection, create_station_table)
# Out:
# Query executed successfully
# Query executed successfully
# Query executed successfully

# %% [markdown]
# Insert data from dataframe to sqlite database

# %%
join_df[["restaurant id","address","distance"]].to_sql("restaurant_location", connection,if_exists='replace',index=False)
join_df[["restaurant id","station id","name","price","review_count","rating"]].to_sql("restaurant_info", connection,if_exists='replace',index=False)
station_df[["station id","latitude","longitude","number of bikes"]].to_sql("station", connection,if_exists='replace',index=False)
# Out:
# 737

# %% [markdown]
# Define read querry function

# %%
def execute_read_query(connection, query):
    cursor = connection.cursor()
    result = None
    try:
        cursor.execute(query)
        result = cursor.fetchall()
        return result
    except Error as e:
        print(f"The error '{e}' occurred")

# %% [markdown]
# Join table to validate data

# %%
select_users = """
SELECT ri."restaurant id",ri."name",ri."price",ri."review_count",ri."rating",rl."address",rl."distance",s."station id",s."latitude",s."longitude",s."number of bikes"
FROM restaurant_info AS ri
JOIN station AS s ON ri."station id" = s."station id"
JOIN restaurant_location AS rl ON rl."restaurant id" = ri."restaurant id"
LIMIT 10
"""

# %%
users = execute_read_query(connection, select_users)
for user in users:
    print(user)
# Out:
# (1, 'Mejana', 2.0, 814, 8.0, '2300 Wilson Blvd', 210.57419734291352, 1.0, 38.890612, -77.084801, 0.0)
# (4, 'Courthaus Social', 2.0, 481, 8.0, '2300 Clarendon Blvd', 199.4250353330203, 1.0, 38.890612, -77.084801, 0.0)
# (6, 'Green Pig Bistro', 2.0, 1109, 8.0, '1025 N Fillmore St', 845.4538266928838, 1.0, 38.890612, -77.084801, 0.0)
# (7, 'Brass Rabbit Pub', 2.0, 96, 9.0, '1210 N Garfield St', 885.4332557827812, 1.0, 38.890612, -77.084801, 0.0)
# (9, 'Fire Works Pizza', 2.0, 865, 8.05, '2350 Clarendon Blvd', 230.52331013754133, 1.0, 38.890612, -77.084801, 0.0)
# (10, 'Burger District Gourmet Burgers and Bar', 2.0, 278, 8.0, '2024 Wilson Blvd', 229.3206660224552, 1.0, 38.890612, -77.084801, 0.0)
# (11, 'Three Whistles', 1.0, 86, 9.0, '2719 Wilson Blvd', 567.1484863172517, 1.0, 38.890612, -77.084801, 0.0)
# (12, 'Buena Vida', 2.0, 434, 8.0, '2900 Wilson Blvd', 777.8530833894142, 1.0, 38.890612, -77.084801, 0.0)
# (13, 'Takeshi Sushi', 2.0, 138, 9.0, '2424 Wilson Blvd', 295.37622541044686, 1.0, 38.890612, -77.084801, 0.0)
# (14, 'Verre Wine Bar', 2.0, 165, 8.6, '2415 Wilson Blvd', 243.69010962315195, 1.0, 38.890612, -77.084801, 0.0)
